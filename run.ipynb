# %%
# !pip3 install -v -e .
# Out:
# Using pip 25.1 from C:\Users\Wave\.conda\envs\yolox\lib\site-packages\pip (python 3.10)
# Obtaining file:///D:/git/YOLOX-custom
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Attempting uninstall: yolox
#     Found existing installation: yolox 0.3.0
#     Uninstalling yolox-0.3.0:
#       Removing file or directory c:\users\wave\.conda\envs\yolox\lib\site-packages\yolox.egg-link
#       Removing pth entries from c:\users\wave\.conda\envs\yolox\lib\site-packages\easy-install.pth:
#       Removing entry: d:\git\yolox-custom
#       Successfully uninstalled yolox-0.3.0
#   Running setup.py develop for yolox
# ...
#   Running command python setup.py egg_info
#   C:\Users\Wave\.conda\envs\yolox\lib\site-packages\setuptools\__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
# ...

# %%
# !set PATH=C:\Users\Admin\Documents\Work\passport\[yolox] train-passport-detection\yolox-env\Lib\site-packages\torch\lib;C:\Users\Admin\Documents\Work\passport\[yolox] train-passport-detection\yolox-env\Scripts

# %%
# !python tools/train.py -f exps/default/yolox_nano_passport.py -d 1 -b 16 --fp16 -o
# Out:
# d:\git\yolox-custom\yolox\core\trainer.py:47: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=args.fp16)
# c:\Users\Wave\.conda\envs\yolox\lib\site-packages\torch\amp\grad_scaler.py:136: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 2025-07-04 09:16:40 | INFO     | yolox.core.trainer:132 - args: Namespace(experiment_name='yolox_nano_passport', name=None, dist_backend='nccl', dist_url=None, batch_size=16, devices=1, exp_file='exps/default/yolox_nano_passport.py', resume=False, ckpt=None, start_epoch=None, num_machines=1, machine_rank=0, fp16=True, cache=None, occupy=True, logger='tensorboard', opts=[])
# 2025-07-04 09:16:40 | INFO     | yolox.core.trainer:133 - exp value:
# ╒═══════════════════╤═════════════════════════════════════════════╕
# ...

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# !pip3 uninstall torch torchvision torchaudio
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -------------------------------------- - 4.5/4.7 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 21.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.3 GB ? eta -:--:--
#    ---------------------------------------- 0.0/3.3 GB 20.9 MB/s eta 0:02:37
#    ---------------------------------------- 0.0/3.3 GB 20.8 MB/s eta 0:02:38
#    ---------------------------------------- 0.0/3.3 GB 22.1 MB/s eta 0:02:28
#    ---------------------------------------- 0.0/3.3 GB 23.1 MB/s eta 0:02:21
#    ---------------------------------------- 0.0/3.3 GB 24.1 MB/s eta 0:02:15
#    ---------------------------------------- 0.0/3.3 GB 25.1 MB/s eta 0:02:10
#    ---------------------------------------- 0.0/3.3 GB 24.8 MB/s eta 0:02:11
#     --------------------------------------- 0.0/3.3 GB 25.6 MB/s eta 0:02:07
# ...

# %%
import torch
print(torch.cuda.is_available())
print("Torch version:", torch.__version__)
# Out:
# True
# Torch version: 2.5.1+cu121

# %%
# !nvidia-smi
# Out:
# Fri Jul  4 09:29:35 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.02                 Driver Version: 576.02         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070      WDDM  |   00000000:0A:00.0  On |                  N/A |
# |  0%   31C    P8             21W /  270W |    2098MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python -m yolox.tools.eval -n  yolox-nano -c yolox_nano.pth -b 1 -d 1 --conf 0.001 --fp16 --fuse
# Out:
# Exception ignored in: <function CacheDataset.__del__ at 0x0000018785DE83A0>
# Traceback (most recent call last):
#   File "d:\git\YOLOX-custom\yolox\data\datasets\datasets_wrapper.py", line 177, in __del__
#     if self.cache and self.cache_type == "ram":
# AttributeError: 'COCODataset' object has no attribute 'cache'
# 2025-07-11 19:28:29 | INFO     | __main__:139 - Args: Namespace(experiment_name='yolox_nano', name='yolox-nano', dist_backend='nccl', dist_url=None, batch_size=1, devices=1, num_machines=1, machine_rank=0, exp_file=None, ckpt='yolox_nano.pth', conf=0.001, nms=None, tsize=None, seed=None, fp16=True, fuse=True, trt=False, legacy=False, test=False, speed=False, opts=[])
# 2025-07-11 19:28:29 | INFO     | __main__:149 - Model Summary: Params: 0.91M, Gflops: 1.11
# 2025-07-11 19:28:29 | INFO     | __main__:150 - Model Structure:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
# ...
